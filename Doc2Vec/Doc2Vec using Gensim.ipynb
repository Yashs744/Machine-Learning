# %% [markdown]
# # Doc2Vec
# Doc2Vec using Gensim and Python.
#
# <b>Author:</b> Yash Sharma<br />
# <b>Created On:</b> 9th Septembe, 2017
#
# <b> Libraries Used:</b>
#
#     Gensim, NLTK, Pandas, OS, Matplotlib, Sklean

# %% [markdown]
# ## Dependencies

# %%
import gensim
import pandas as pd
from nltk import RegexpTokenizer
from nltk.corpus import stopwords
from os import listdir
from os.path import isfile, join

from sklearn.manifold import TSNE
from matplotlib import pylab
# Out:
# c:\users\yash sharma\appdata\local\programs\python\python35\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %% [markdown]
# ## Loading Files into the Memory
# A Total of 100 Documents (News Articles on Science) in Doc2Vec Sample Dir.<br />

# %%
# List of FileNames in the Doc2Vec Sample Directory.
docLabels = [f for f in listdir('Doc2Vec Sample/')]

# Data Content of each file.
data = []
for doc in docLabels:
    data.append(open('Doc2Vec Sample/' + doc).read())

# %% [markdown]
# ## Iterator Object
# <i>Labeled_Sentences</i> class collects all documents from passed list <b>docList</b> and corresponding <b>labelsList</b> and <b>returns</b> an iterator over those documents

# %%
class Labeled_Sentences(object):
    def __init__(self, docList, labelsList):
        self.labels_list = labelsList
        self.doc_list = docList
        
    def __iter__(self):
        for idx, doc in enumerate(self.doc_list):
            yield gensim.models.doc2vec.LabeledSentence(
                doc, [self.labels_list[idx]]
            )

# %% [markdown]
# ## Pre-Processing Text
# PreProcessing is one of the most important task we perform before building the model.
#
# Here, we are converting the content (text) to tokens and then removing stopwords from the newly created tokens.

# %%
# Set of StopWords from English Dictionary
stopWords = set(stopwords.words('english'))

# Initializing the Regex Tokenizer
# We can use any Tokenizer.
tokenizer = RegexpTokenizer(r'\w+')

# %%
def PreProcess(data):
    new_data = []
    for d in data:
        # Convert data to lower case
        d = d.lower()
        # Tokenize the content
        tokens = tokenizer.tokenize(d)
        # Remove StopWords
        tokens = list(set(tokens).difference(stopWords))
        
        # Append the Processed Data (Content) to the list
        new_data.append(tokens)
        
    # Return the New Data List.
    return new_data

# %%
# Cleaning (PreProcessing)
data = PreProcess(data)

# %% [markdown]
# #### After Pre-Processing the Content we have
#
#     docLabels containing Unique Labels for each Document.
#     data containing corresponding data for that Document.
#
# Next, pass these to the <i>Labeled_Sentences</i> class to get a Iterator Object.

# %%
# Calling the Labeled_Sentences Class.
# data -> Text Content of each Document.
# docLabels -> Name of the Document corresponding to the Content.
it = Labeled_Sentences(data, docLabels)

# %% [markdown]
# ## Doc2Vec Model
# ### Parameters:
#     size: Number of Features<br/>
#     alpha: Learning Rate<br />
#     min_count: To Neglect InFrequent Words.

# %%
model = gensim.models.Doc2Vec(size = 300, min_count=0, 
                              alpha = 0.025, min_alpha = 0.025)
model.build_vocab(it)

# %% [markdown]
# ### Training the Model

# %%
model.train(it, total_examples=model.corpus_count, epochs=100)
# Out:
# 334873

# %% [markdown]
# ### Save the Trained Model

# %%
model.save('doc2vec.model')
print ("Model Saved")
# Out:
# Model Saved

# %% [markdown]
# ## Let's Play
# ### Documents which are Most Similar

# %%
# To get most similar document with similarity scores using document-index
similar_doc = model.docvecs.most_similar(5)

# %%
pd.DataFrame(similar_doc, columns=['Document', 'Score'])
# Out:
#                                             Document     Score
# 0  Asteroid impact in ocean may vaporise 250 mn t...  0.735780
# 1  Artificial intelligence can destroy society St...  0.726180
# 2                  Are we alone in the universe .txt  0.692185
# 3  Asteroid collision with Earth inevitable, warn...  0.675604
# 4  Apple hires MIT student who 3D printed his own...  0.673789
# 5  Alps could lose 70% of their snow cover by 210...  0.668411
# 6  Battery-less implantable device powered by bod...  0.665988
# 7  Printable solar cells to turn surfaces into po...  0.664394
# 8  Antibody that neutralises 98% HIV strains iden...  0.648427
# 9  Project 'City of Trees' aims to plant 30 lakh ...  0.647168

# %% [markdown]
# ### Vocabulary

# %%
model.wv.vocab
# Out:
# {'conditions': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb9e8>,
#  'hired': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcdef0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf1d0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf320>,
#  'flowing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf358>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf400>,
#  'dubbed': <gensim.models.keyedvectors.Vocab at 0x1a9b6005fd0>,
#  '19': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf4a8>,
#  'mount': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf518>,
#  'bdellovibrio': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1c88>,
#  '76': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf5c0>,
#  'firms': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf5f8>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf668>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf6a0>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf6d8>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf710>,
#  'symptoms': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7cf8>,
#  'seedlings': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf780>,
#  'fearing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf7b8>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea898>,
#  'hydrogen': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf828>,
#  'hemisphere': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf860>,
#  'hotter': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf898>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf8d0>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf908>,
#  'spectrum': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf940>,
#  'detectable': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf978>,
#  'bubbling': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf9b0>,
#  'spiders': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf9e8>,
#  'nodosaur': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a7b8>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfa58>,
#  'tyrrell': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfa90>,
#  'mating': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfac8>,
#  'mode': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfb00>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfb38>,
#  'recommended': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf208>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfbe0>,
#  'facilitates': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfc18>,
#  'continent': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfcc0>,
#  'opposite': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1dd8>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfd68>,
#  'detected': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfda0>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfdd8>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x1a9b6005198>,
#  'november': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfe10>,
#  'forelegs': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea9e8>,
#  'electricity': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1198>,
#  'satellite': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcff28>,
#  'devices': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1438>,
#  'polar': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcff98>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcffd0>,
#  'maritime': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97048>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97080>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x1a9b5f970b8>,
#  'shut': <gensim.models.keyedvectors.Vocab at 0x1a9b5f970f0>,
#  'empty': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97128>,
#  'acted': <gensim.models.keyedvectors.Vocab at 0x1a9b60055c0>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97198>,
#  'facedown': <gensim.models.keyedvectors.Vocab at 0x1a9b5f971d0>,
#  'retrograde': <gensim.models.keyedvectors.Vocab at 0x1a9b60004e0>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97208>,
#  'represented': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97240>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97278>,
#  'supply': <gensim.models.keyedvectors.Vocab at 0x1a9b5f972b0>,
#  'copper': <gensim.models.keyedvectors.Vocab at 0x1a9b5f972e8>,
#  'mostly': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97320>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97358>,
#  'miniature': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97390>,
#  'hypothesised': <gensim.models.keyedvectors.Vocab at 0x1a9b6008eb8>,
#  'jupiter': <gensim.models.keyedvectors.Vocab at 0x1a9b5f973c8>,
#  'particles': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97400>,
#  'shelf': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97438>,
#  'tweeted': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97470>,
#  'slumping': <gensim.models.keyedvectors.Vocab at 0x1a9b5f974a8>,
#  'webbing': <gensim.models.keyedvectors.Vocab at 0x1a9b5f974e0>,
#  'plants': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97518>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97550>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97588>,
#  'reached': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfe48>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x1a9b5f975f8>,
#  'locations': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97630>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf400>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x1a9b5f976a0>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x1a9b5feab70>,
#  'assembles': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97710>,
#  'diet': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97748>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97780>,
#  'warmest': <gensim.models.keyedvectors.Vocab at 0x1a9b5f977b8>,
#  'silencing': <gensim.models.keyedvectors.Vocab at 0x1a9b5f977f0>,
#  'smuggled': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97828>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaac8>,
#  'floated': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff7668>,
#  'inches': <gensim.models.keyedvectors.Vocab at 0x1a9b5f978d0>,
#  'ancestors': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97908>,
#  'represents': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97940>,
#  'coat': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97978>,
#  'markedly': <gensim.models.keyedvectors.Vocab at 0x1a9b5f979b0>,
#  'involves': <gensim.models.keyedvectors.Vocab at 0x1a9b5f979e8>,
#  'overweight': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc160>,
#  '75': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97a58>,
#  'geologically': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97a90>,
#  'contains': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97ac8>,
#  'otherwise': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97b00>,
#  'california': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97b38>,
#  'catastrophic': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97b70>,
#  'neutralised': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5048>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97be0>,
#  'metre': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97c18>,
#  'fund': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97c50>,
#  'dramatically': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcc88>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97cf8>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x1a9b6008d30>,
#  '1928': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97d30>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97d68>,
#  'cheaper': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97da0>,
#  'disrespect': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97dd8>,
#  'lows': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97e10>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97e48>,
#  'riverbed': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff77b8>,
#  'threads': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97eb8>,
#  'rise': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97ef0>,
#  'microbes': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97f28>,
#  'alaska': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97f60>,
#  '77': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97f98>,
#  'kgs': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97fd0>,
#  'magnetic': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a048>,
#  'costs': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a080>,
#  'protein': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb4a8>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a0f0>,
#  'vulnerable': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a128>,
#  'extinct': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a160>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a198>,
#  'gever': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a1d0>,
#  'summers': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff7c50>,
#  'greenhouse': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a240>,
#  'organ': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a2b0>,
#  'winged': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a2e8>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a320>,
#  'tightness': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a358>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a390>,
#  'deceased': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a3c8>,
#  'â': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a400>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a4a8>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a4e0>,
#  'epidermodysplasia': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a518>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a588>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a5c0>,
#  'forming': <gensim.models.keyedvectors.Vocab at 0x1a9b6005588>,
#  'january': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a5f8>,
#  'wednesday': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a630>,
#  'tens': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a668>,
#  'melting': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a6a0>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a6d8>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a710>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a748>,
#  'demonstrated': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7fd0>,
#  'confirmed': <gensim.models.keyedvectors.Vocab at 0x1a9b60105c0>,
#  'cells': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea208>,
#  'armoured': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea128>,
#  'dwarf': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a860>,
#  'mummies': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5320>,
#  'jokingly': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a8d0>,
#  'onset': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a908>,
#  'allows': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a940>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1240>,
#  'delayed': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a9b0>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a9e8>,
#  'electrolyte': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda7b8>,
#  'hollow': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9aa58>,
#  'browning': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9aa90>,
#  'legal': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9aac8>,
#  'industry': <gensim.models.keyedvectors.Vocab at 0x1a9b60108d0>,
#  'anna': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ab00>,
#  'memories': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1160>,
#  'defines': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ab70>,
#  'maize': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9aba8>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9abe0>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ac18>,
#  'cap': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ac50>,
#  'monitor': <gensim.models.keyedvectors.Vocab at 0x1a9b5feae80>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9acc0>,
#  'tonnes': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9acf8>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ad30>,
#  'voters': <gensim.models.keyedvectors.Vocab at 0x1a9b6005240>,
#  'litres': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ada0>,
#  'thirds': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9add8>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ae10>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ae48>,
#  'linked': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9aeb8>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9af28>,
#  'printout': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9af60>,
#  'israel': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9af98>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9afd0>,
#  'spacewalk': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e048>,
#  'arctic': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e080>,
#  'chinese': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e0b8>,
#  'aims': <gensim.models.keyedvectors.Vocab at 0x1a9b600e198>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaf28>,
#  'jersey': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e128>,
#  'accidentally': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaf60>,
#  'hypotheses': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5438>,
#  'orbits': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e1d0>,
#  'designed': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e240>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e278>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e2b0>,
#  'draco': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e2e8>,
#  'planting': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e320>,
#  'throat': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e358>,
#  'embedded': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e390>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e3c8>,
#  '96': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e400>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff72e8>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e470>,
#  'collected': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e4a8>,
#  'siberia': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e4e0>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e518>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e550>,
#  'survive': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e588>,
#  'chemically': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e5c0>,
#  'bus': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e5f8>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e630>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5518>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e6a0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1a9b6010470>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e6d8>,
#  'tipping': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e710>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e748>,
#  'newly': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e780>,
#  'elements': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e7b8>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e7f0>,
#  'metal': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e860>,
#  'mouse': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e898>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e8d0>,
#  'feat': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e908>,
#  '600': <gensim.models.keyedvectors.Vocab at 0x1a9b60056d8>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e940>,
#  'patients': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e978>,
#  'vibrations': <gensim.models.keyedvectors.Vocab at 0x1a9b600e940>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e9b0>,
#  '151': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e9e8>,
#  'egyptian': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ea20>,
#  'gases': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ea90>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9eb00>,
#  'rib': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9eb38>,
#  'creature': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9eb70>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9eba8>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ebe0>,
#  'newborn': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ec18>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ec50>,
#  'spaceflight': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf828>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ecc0>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ecf8>,
#  'abilities': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ed30>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ed68>,
#  'sneaking': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9eda0>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9edd8>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ee10>,
#  'lithium': <gensim.models.keyedvectors.Vocab at 0x1a9b6005b70>,
#  'serpent': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ee48>,
#  'notably': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ee80>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x1a9b6010358>,
#  'deterrence': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9eef0>,
#  'icy': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ef28>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ef60>,
#  'proteins': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9efd0>,
#  'bbc': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1d30>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1080>,
#  'immunodeficiency': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd10b8>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd10f0>,
#  'societal': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1128>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfef0>,
#  'neeson': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd11d0>,
#  'spider': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1208>,
#  'weekly': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd12b0>,
#  '1907': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd12e8>,
#  'farmers': <gensim.models.keyedvectors.Vocab at 0x1a9b6005c18>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1358>,
#  'harming': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1390>,
#  'transform': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5780>,
#  'insects': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1400>,
#  'frost': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcff60>,
#  'flowed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1470>,
#  'peggy': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd57b8>,
#  'co2': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd14e0>,
#  'unearthed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1518>,
#  'midnight': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9aa20>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1588>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd15c0>,
#  'matrix': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1630>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1668>,
#  'pushed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd16a0>,
#  'kmph': <gensim.models.keyedvectors.Vocab at 0x1a9b600ac18>,
#  'chile': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd16d8>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1710>,
#  'canada': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1748>,
#  'accidental': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1780>,
#  'spikes': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd17b8>,
#  'harvard': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd17f0>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1828>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1860>,
#  'headless': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1898>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd18d0>,
#  'engineers': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1908>,
#  'injection': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1940>,
#  '06âºc': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1978>,
#  'conceived': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd19b0>,
#  'tossed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd19e8>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1a20>,
#  'artificial': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1a58>,
#  'zikv': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1a90>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1ac8>,
#  'partner': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1b00>,
#  'marked': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1b38>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1b70>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1ba8>,
#  'task': <gensim.models.keyedvectors.Vocab at 0x1a9b60009e8>,
#  'crumbs': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff7ef0>,
#  'playfully': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1c50>,
#  'preserving': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf588>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1cc0>,
#  'belief': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1cf8>,
#  'gb': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1d68>,
#  'rocks': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1da0>,
#  'manchester': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfcf8>,
#  'uk': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaa58>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1e10>,
#  'liam': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1e48>,
#  'surface': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1e80>,
#  'stephen': <gensim.models.keyedvectors.Vocab at 0x1a9b600ef98>,
#  'fitzsimmons': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1eb8>,
#  'sunspot': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1ef0>,
#  'worldwide': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1f28>,
#  'larger': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1f60>,
#  'russian': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1f98>,
#  'compound': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd1fd0>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97ba8>,
#  'reviewed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5080>,
#  'flood': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd50b8>,
#  'bacteria': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd50f0>,
#  'items': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5160>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5198>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd51d0>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5208>,
#  'nearest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5978>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5278>,
#  'nepal': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd52b0>,
#  'curiosity': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff79e8>,
#  'undergoing': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a898>,
#  'prevents': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5358>,
#  'fischer': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5390>,
#  'device': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd53c8>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5400>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e198>,
#  'crore': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5470>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd54a8>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd54e0>,
#  'scientist': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e668>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5550>,
#  'carbon': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5588>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd55c0>,
#  'roman': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd55f8>,
#  'participants': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5630>,
#  'peer': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5a58>,
#  'expedition': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd56a0>,
#  'interfederal': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd56d8>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5710>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5748>,
#  'maryland': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd13c8>,
#  'shower': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd14a8>,
#  'thomas': <gensim.models.keyedvectors.Vocab at 0x1a9b6005860>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed400>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5828>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed588>,
#  'chemical': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd58d0>,
#  'weighs': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5b00>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x1a9b6005eb8>,
#  'ai': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5240>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd59b0>,
#  'shrink': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd59e8>,
#  'whitson': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5a20>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5668>,
#  'cooler': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5ac8>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5908>,
#  '332': <gensim.models.keyedvectors.Vocab at 0x1a9b6005b00>,
#  'campaigners': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5b38>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5b70>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5ba8>,
#  'doctoral': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdafd0>,
#  'warned': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5c18>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5c50>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5cc0>,
#  'lesions': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5cf8>,
#  'recognition': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5d30>,
#  'march': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5d68>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x1a9b6000cc0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5da0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5dd8>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5e10>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5e48>,
#  'lufengosaurus': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5e80>,
#  'colonies': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5eb8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5ef0>,
#  'cancelled': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5f28>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed6a0>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda518>,
#  'breaks': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5fd0>,
#  'oxidant': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7048>,
#  'announced': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7080>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd70b8>,
#  '450': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd70f0>,
#  'enceladus': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7128>,
#  'bioterrorism': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7160>,
#  'reobserved': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5be0>,
#  'eyal': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdad68>,
#  'concerns': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7208>,
#  'bat': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd72b0>,
#  'behaviour': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd72e8>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb240>,
#  'stored': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7358>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7390>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd73c8>,
#  'uncontrollable': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc588>,
#  'biosupercapacitor': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7438>,
#  'diets': <gensim.models.keyedvectors.Vocab at 0x1a9b6000390>,
#  'adults': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7470>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff5748>,
#  'assassin': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd74e0>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed748>,
#  'bug': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7550>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7588>,
#  'parallel': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf240>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd75f8>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7630>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7668>,
#  'rock': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd76a0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd76d8>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7710>,
#  'approximately': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7748>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7780>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd77b8>,
#  'reflected': <gensim.models.keyedvectors.Vocab at 0x1a9b600a9b0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd77f0>,
#  'japanese': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7828>,
#  'genetically': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7860>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7898>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd78d0>,
#  'antibiotic': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed7f0>,
#  'mit': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7940>,
#  'unveiled': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7978>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd79b0>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7a20>,
#  'objects': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7a58>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7a90>,
#  'synapses': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7ac8>,
#  'thymic': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7b00>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7b38>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7b70>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7ba8>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7be0>,
#  'bind': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7c18>,
#  'arguing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7c50>,
#  'billionaire': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7c88>,
#  'israeli': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed8d0>,
#  'agricultural': <gensim.models.keyedvectors.Vocab at 0x1a9b60104e0>,
#  'pairs': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7d30>,
#  'downward': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7d68>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7da0>,
#  '2030s': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7dd8>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x1a9b60109b0>,
#  'avoiding': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7e10>,
#  'transitioning': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed940>,
#  'fools': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7e80>,
#  'mice': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8940>,
#  '1942': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7ef0>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb4e0>,
#  'causing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7f60>,
#  'iss': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7f98>,
#  'launching': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda048>,
#  'quadrantid': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda0b8>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda0f0>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb550>,
#  'trigger': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda160>,
#  'strands': <gensim.models.keyedvectors.Vocab at 0x1a9b600a080>,
#  'european': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda198>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda1d0>,
#  '5â': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda208>,
#  'versions': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda240>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x1a9b6005518>,
#  'arrow': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda278>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda2b0>,
#  'bulgarian': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda2e8>,
#  'kinds': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda320>,
#  '13': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed2e8>,
#  'cloud': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda390>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda3c8>,
#  'servings': <gensim.models.keyedvectors.Vocab at 0x1a9b5fedb00>,
#  'download': <gensim.models.keyedvectors.Vocab at 0x1a9b600e978>,
#  'expression': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5f60>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda470>,
#  'merge': <gensim.models.keyedvectors.Vocab at 0x1a9b5fede10>,
#  'remained': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda4e0>,
#  'troposphere': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7198>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd5f98>,
#  'beamed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda550>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda588>,
#  'ant': <gensim.models.keyedvectors.Vocab at 0x1a9b600a780>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda5c0>,
#  'resistant': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda5f8>,
#  'bangalore': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda668>,
#  'pioneered': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda6a0>,
#  'attached': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda6d8>,
#  'collaborated': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda710>,
#  'mosasaur': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda748>,
#  'bees': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda780>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8da0>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda828>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda860>,
#  'raise': <gensim.models.keyedvectors.Vocab at 0x1a9b6000438>,
#  'replaced': <gensim.models.keyedvectors.Vocab at 0x1a9b600eba8>,
#  'added': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda898>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda8d0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1a9b6008390>,
#  'paint': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb668>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda940>,
#  'replace': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff5390>,
#  'competition': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda9b0>,
#  'famous': <gensim.models.keyedvectors.Vocab at 0x1a9b5fda9e8>,
#  'killing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaa20>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaa58>,
#  '18âºc': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaa90>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97860>,
#  '800': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdab00>,
#  'weightlessness': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdab38>,
#  'organisms': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdab70>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaba8>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdabe0>,
#  'thymus': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdac18>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdac50>,
#  'teams': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdac88>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff76a0>,
#  'sexy': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdacf8>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2d68>,
#  'discusses': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdad30>,
#  'tongue': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff2da0>,
#  'tools': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdada0>,
#  'museum': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdadd8>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdae10>,
#  'sits': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdae48>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdae80>,
#  '110': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaeb8>,
#  'roughly': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaef0>,
#  'distinguishing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaf28>,
#  '54': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaf60>,
#  'projected': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdaf98>,
#  'processing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc048>,
#  'packing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd71d0>,
#  'hawking': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc080>,
#  'achieved': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc0b8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb828>,
#  'marine': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc128>,
#  'structures': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97a20>,
#  'infected': <gensim.models.keyedvectors.Vocab at 0x1a9b6008ac8>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc198>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc1d0>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc208>,
#  'reuse': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc240>,
#  'pregnancies': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7320>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc2b0>,
#  'scaled': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb278>,
#  'vascular': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc2e8>,
#  'audition': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc320>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc358>,
#  'lizards': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc390>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc3c8>,
#  '3400': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc400>,
#  'eh1': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc438>,
#  'trojans': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc470>,
#  'platform': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc4a8>,
#  'superbugs': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc4e0>,
#  'seabed': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb908>,
#  'administration': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc550>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7400>,
#  'landslides': <gensim.models.keyedvectors.Vocab at 0x1a9b6002160>,
#  'completed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc5f8>,
#  'stages': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc630>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc668>,
#  'wing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc6a0>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc6d8>,
#  'landscapes': <gensim.models.keyedvectors.Vocab at 0x1a9b6008630>,
#  'coal': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc748>,
#  '1951': <gensim.models.keyedvectors.Vocab at 0x1a9b6005080>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc780>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc7b8>,
#  'destroyed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc7f0>,
#  'british': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc828>,
#  'pocket': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc860>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc898>,
#  'severed': <gensim.models.keyedvectors.Vocab at 0x1a9b6008ba8>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc8d0>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc908>,
#  'fondue': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc940>,
#  'adapting': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc978>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdc9b0>,
#  'wearable': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdca20>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdca58>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffba90>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcb00>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x1a9b6008780>,
#  'perovskite': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcb70>,
#  'responds': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcba8>,
#  'showing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcbe0>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcc50>,
#  'powered': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdccc0>,
#  'seat': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcd30>,
#  'eliminating': <gensim.models.keyedvectors.Vocab at 0x1a9b600e470>,
#  '562': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcd68>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcda0>,
#  'bangladeshi': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcdd8>,
#  'uptake': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdce10>,
#  'laugh': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdce48>,
#  'observed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdce80>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdceb8>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcef0>,
#  'foundation': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcf28>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffbb70>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcf60>,
#  'eastern': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcf98>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdcfd0>,
#  'electromagnetic': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf048>,
#  'bark': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf080>,
#  'starch': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf0b8>,
#  'anxiety': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf0f0>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf128>,
#  'geologists': <gensim.models.keyedvectors.Vocab at 0x1a9b5fede80>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffbba8>,
#  'emily': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf1d0>,
#  'experienced': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a278>,
#  'orbit': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd75c0>,
#  'neurons': <gensim.models.keyedvectors.Vocab at 0x1a9b6008978>,
#  'debris': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf2b0>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf2e8>,
#  'nasa': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf320>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e208>,
#  'verruciformis': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf390>,
#  'naturally': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf3c8>,
#  'meteor': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed668>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf438>,
#  'nanoparticles': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf470>,
#  'preserve': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf4a8>,
#  'sudden': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf4e0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x1a9b6010400>,
#  'containing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf518>,
#  'visible': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf550>,
#  'cultivated': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf588>,
#  'altitude': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf5c0>,
#  'volumes': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf5f8>,
#  'orchards': <gensim.models.keyedvectors.Vocab at 0x1a9b5fedf28>,
#  'examining': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf668>,
#  'journals': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf6a0>,
#  'estimated': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf710>,
#  'catastrophe': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2978>,
#  'imaged': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf780>,
#  'astronaut': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2710>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf7f0>,
#  'episodes': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf860>,
#  'lowlands': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf898>,
#  'burials': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef048>,
#  'biggest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf908>,
#  'lowest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf940>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf978>,
#  'strongest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf9b0>,
#  'midwest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdf9e8>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfa20>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfa58>,
#  'wind': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfa90>,
#  'detects': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfac8>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfb00>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfb38>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x1a9b6008b38>,
#  'pointed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfb70>,
#  'samples': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfba8>,
#  'lunar': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfc18>,
#  'populations': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd15f8>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfc88>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfcc0>,
#  'andes': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfcf8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfd30>,
#  'dummy': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfd68>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfda0>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfdd8>,
#  'gravity': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfe10>,
#  'northamptonshire': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfe48>,
#  'named': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfe80>,
#  'obese': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdfeb8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff5e80>,
#  'crack': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdff28>,
#  'moss': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdff60>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdff98>,
#  'cambridge': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdffd0>,
#  'abundant': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2048>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x1a9b6008c18>,
#  'jeff': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe20b8>,
#  'bumblebees': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2128>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2160>,
#  'measuring': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2198>,
#  'asteroids': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe21d0>,
#  'n6': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2208>,
#  'hunters': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2240>,
#  'himalayan': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2278>,
#  'blocking': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe22b0>,
#  '195': <gensim.models.keyedvectors.Vocab at 0x1a9b5f97668>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe22e8>,
#  'slicing': <gensim.models.keyedvectors.Vocab at 0x1a9b6008cf8>,
#  'kg': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe45c0>,
#  'reveals': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2358>,
#  'communicate': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2390>,
#  'layer': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe23c8>,
#  'weightless': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2400>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2438>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2470>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe24a8>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe24e0>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x1a9b600efd0>,
#  'giss': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2518>,
#  'improved': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4240>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2588>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe25c0>,
#  'ejected': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe25f8>,
#  'hitting': <gensim.models.keyedvectors.Vocab at 0x1a9b6008f98>,
#  'aquatic': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2630>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2668>,
#  'yukimarimo': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe26a0>,
#  'atmospheric': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe26d8>,
#  'resulting': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef390>,
#  'indicated': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2748>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2780>,
#  'mountains': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe27b8>,
#  'vtol': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe27f0>,
#  'producing': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb630>,
#  'revolve': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2898>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2908>,
# ...
#  'voice': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2c18>,
#  'thiel': <gensim.models.keyedvectors.Vocab at 0x1a9b5fdccf8>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2c88>,
#  'algorithms': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2cc0>,
#  '1930': <gensim.models.keyedvectors.Vocab at 0x1a9b6000898>,
#  'explores': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2d30>,
#  'preventive': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a0b8>,
#  'erupting': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2da0>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2dd8>,
#  'centre': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2e48>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2e80>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x1a9b600e6d8>,
#  'meteorological': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2eb8>,
#  'ladybird': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8978>,
#  'isotope': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7240>,
#  'celebrities': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2f60>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff5320>,
#  'exercise': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2fd0>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4048>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4080>,
#  'begonia': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe40b8>,
#  'apparent': <gensim.models.keyedvectors.Vocab at 0x1a9b5feafd0>,
#  'snap': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4128>,
#  'apes': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4160>,
#  'captured': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4198>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x1a9b5feadd8>,
#  'delete': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff24a8>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4278>,
#  'ariane': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe42b0>,
#  'modified': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe42e8>,
#  'cassini': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2b00>,
#  '117': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed320>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x1a9b6002c18>,
#  'universe': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed908>,
#  'friday': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4400>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4438>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4470>,
#  'diameter': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe44a8>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe44e0>,
#  'delivered': <gensim.models.keyedvectors.Vocab at 0x1a9b5fedda0>,
#  'booked': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4550>,
#  'gus': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4588>,
#  'astronauts': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea940>,
#  'ecosystems': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe45f8>,
#  'camera': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef860>,
#  'administered': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4668>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef9e8>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef630>,
#  '200th': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4710>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4748>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1a9b5fefef0>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe47b8>,
#  'biocompatible': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe47f0>,
#  'grinding': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4828>,
#  'intake': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff22b0>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4898>,
#  'tonne': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe48d0>,
#  'handed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4908>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe2be0>,
#  'egypt': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4978>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe49b0>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff5128>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4a20>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4a58>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4ac8>,
#  'mechanical': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff5a90>,
#  'alien': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4b38>,
#  'weak': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4b70>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffd550>,
#  'spacecraft': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4be0>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4c18>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4c50>,
#  'astrophysicist': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4c88>,
#  '2014': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4cf8>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4d30>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4d68>,
#  'resurrect': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4da0>,
#  'selective': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4dd8>,
#  '1983': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4e10>,
#  'sedimentary': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4e80>,
#  'bones': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4eb8>,
#  'smog': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4ef0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4f28>,
#  'engulfed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4f60>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4f98>,
#  'rarest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4fd0>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffdf98>,
#  'linking': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff7780>,
#  'ppo': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8048>,
#  'deficient': <gensim.models.keyedvectors.Vocab at 0x1a9b6005cf8>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe80b8>,
#  'strengthen': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ef98>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8128>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8160>,
#  'debut': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8198>,
#  'bc': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe81d0>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x1a9b60085c0>,
#  'hiv': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8208>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8240>,
#  'cooling': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffd6d8>,
#  'juno': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8278>,
#  'fiji': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe82b0>,
#  'maintenance': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe82e8>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8320>,
#  'lights': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8358>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe83c8>,
#  'shift': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8400>,
#  'steady': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8438>,
#  'cairo': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8470>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x1a9b5ff7eb8>,
#  'poisoning': <gensim.models.keyedvectors.Vocab at 0x1a9b6000b70>,
#  'probe': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef898>,
#  'shared': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8550>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8588>,
#  'influence': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe85c0>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe85f8>,
#  'variations': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8630>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8668>,
#  'genes': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe86a0>,
#  'produce': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb320>,
#  'hurtling': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8710>,
#  'chest': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8748>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8780>,
#  'becomes': <gensim.models.keyedvectors.Vocab at 0x1a9b600a2e8>,
#  'darkness': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe87f0>,
#  'millions': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd7e48>,
#  'belgium': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8828>,
#  'reoriented': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8860>,
#  'tones': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8898>,
#  'lasting': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe88d0>,
#  'plate': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8908>,
#  'september': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffd7f0>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe89e8>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8a20>,
#  'stratosphere': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8a58>,
#  'bmi': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8ac8>,
#  'zika': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8b00>,
#  'pot': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8b38>,
#  '1858': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8b70>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef4e0>,
#  'waist': <gensim.models.keyedvectors.Vocab at 0x1a9b600a390>,
#  '66': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8c18>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8c50>,
#  'inauguration': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8c88>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed518>,
#  'deposits': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8cc0>,
#  'vacuum': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8cf8>,
#  'creating': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8d30>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1a9b600a4a8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8d68>,
#  'tons': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8dd8>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x1a9b6008cc0>,
#  'archaeological': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8e48>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8e80>,
#  'sowing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8eb8>,
#  'canadian': <gensim.models.keyedvectors.Vocab at 0x1a9b600ec18>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8f28>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8f60>,
#  'bezos': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffb2e8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe8fd0>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea080>,
#  '27': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea0b8>,
#  'scaffold': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea0f0>,
#  'behaves': <gensim.models.keyedvectors.Vocab at 0x1a9b6008a90>,
#  'yuki': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea748>,
#  'describing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fef5f8>,
#  'laughter': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea160>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x1a9b60006d8>,
#  'contributed': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea1d0>,
#  'seals': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9a7f0>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea240>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea2b0>,
#  'reportedly': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea2e8>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea320>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea358>,
#  'crystals': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea390>,
#  'startup': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea3c8>,
#  'resembling': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea400>,
#  'decades': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea438>,
#  'mutilation': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea470>,
#  'phenomenon': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe40f0>,
#  'mask': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea4e0>,
#  'volcano': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea518>,
#  'turning': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea550>,
#  'launched': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea588>,
#  'layered': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea5c0>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd52e8>,
#  'inc': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea5f8>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea630>,
#  'printed': <gensim.models.keyedvectors.Vocab at 0x1a9b6010978>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea668>,
#  'witness': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea6a0>,
#  'cities': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea6d8>,
#  'june': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea710>,
#  'tiny': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea780>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x1a9b6010828>,
#  'upcoming': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea7b8>,
#  'concentrations': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffd518>,
#  'surgeries': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea828>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf748>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcf7f0>,
#  'crew': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea8d0>,
#  'alps': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea908>,
#  'insect': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfa20>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x1a9b5fea9b0>,
#  'successfully': <gensim.models.keyedvectors.Vocab at 0x1a9b5fcfe80>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaa20>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x1a9b5fd79e8>,
#  'shortness': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaa90>,
#  'competitor': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaac8>,
#  'hazardous': <gensim.models.keyedvectors.Vocab at 0x1a9b5feab00>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x1a9b5feab38>,
#  'thinning': <gensim.models.keyedvectors.Vocab at 0x1a9b5f976d8>,
#  'superheavy': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaba8>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x1a9b5feabe0>,
#  'untreatable': <gensim.models.keyedvectors.Vocab at 0x1a9b5feac18>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x1a9b5feac50>,
#  'flyby': <gensim.models.keyedvectors.Vocab at 0x1a9b5feac88>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x1a9b5feacc0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1a9b5feacf8>,
#  '250': <gensim.models.keyedvectors.Vocab at 0x1a9b5fead30>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x1a9b5fead68>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x1a9b5feada0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe41d0>,
#  'los': <gensim.models.keyedvectors.Vocab at 0x1a9b5feae10>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x1a9b5feae48>,
#  'accuracy': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9ac88>,
#  'motion': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaeb8>,
#  'pharma': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaef0>,
#  'flew': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e0f0>,
#  'berkeley': <gensim.models.keyedvectors.Vocab at 0x1a9b5f9e160>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x1a9b5ffdb00>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1a9b6008e10>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x1a9b5feaf98>,
#  'responded': <gensim.models.keyedvectors.Vocab at 0x1a9b5fe4208>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed048>,
#  'electron': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed080>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed0b8>,
#  'rapid': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed0f0>,
#  'calls': <gensim.models.keyedvectors.Vocab at 0x1a9b600a438>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed128>,
#  'unlikely': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed160>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed198>,
#  'wadia': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed1d0>,
#  'gemini': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed208>,
#  'islands': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed240>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x1a9b600a6d8>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x1a9b5fed2b0>,
#  ...}

# %% [markdown]
# ## Plotting the Data

# %%
def plot_data_point(embedding, labels):
    # Print Error and Exit if we hav more labels than Embedding
    assert embedding.shape[0] >= len(labels), 'More Labels than Embeddings'
    
    pylab.clf()
    pylab.figure(figsize=(16,16))
    for i, label in enumerate(labels):
        x, y = embedding[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
        
    pylab.savefig('Doc2Vec.png')

# %%
# List of all the vocabulary
All_Vocab = list(model.wv.vocab)

# %%
# Select Only Top 100
vocab = All_Vocab[:100]
X = model[vocab]

# %%
tSNE = TSNE(n_components=2)
X_tsne = tSNE.fit_transform(X)

# %%
plot_data_point(X_tsne, vocab)
